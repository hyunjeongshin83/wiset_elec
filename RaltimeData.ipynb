# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunjeongshin83/wiset_elec/blob/20240423_wiset_usage_pattern/RaltimeData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import time

# Define the initial voltages and fluctuation range
initial_voltages = {
    'VOLT 1': 1.04, 'VOLT 2': 1.025, 'VOLT 3': 1.025, 'VOLT 4': 1.025788,
    'VOLT 5': 0.995631, 'VOLT 6': 1.012654, 'VOLT 7': 1.025769,
    'VOLT 8': 1.015883, 'VOLT 9': 1.032353
}
fluctuation_range = 0.005

# Function to generate a new row of data
def generate_data(timestamp):
    new_data = {'Time(s)': timestamp}
    for volt in initial_voltages:
        # Generate a random fluctuation around the initial voltage
        new_data[volt] = np.random.normal(initial_voltages[volt], fluctuation_range)
    return new_data

# Generate data every 0.5 seconds
try:
    while True:
        # Simulate the passing of time
        current_time = time.time()
        new_row = generate_data(current_time)
        # Output as a DataFrame row without the index
        print(pd.DataFrame([new_row]).to_string(index=False))
        time.sleep(0.import pandas as pd
import numpy as np
import time

# Define the initial voltages and fluctuation range
initial_voltages = {
    'VOLT 1': 1.04, 'VOLT 2': 1.025, 'VOLT 3': 1.025, 'VOLT 4': 1.025788,
    'VOLT 5': 0.995631, 'VOLT 6': 1.012654, 'VOLT 7': 1.025769,
    'VOLT 8': 1.015883, 'VOLT 9': 1.032353
}
fluctuation_range = 0.005

# Function to generate a new row of data
def generate_data(timestamp):
    new_data = {'Time(s)': timestamp}
    for volt in initial_voltages:
        # Generate a random fluctuation around the initial voltage
        new_data[volt] = np.random.normal(initial_voltages[volt], fluctuation_range)
    return new_data

# Generate data every 0.5 seconds
try:
    while True:
        # Simulate the passing of time
        current_time = time.time()
        new_row = generate_data(current_time)
        # Output as a DataFrame row without the index
        print(pd.DataFrame([new_row]).to_string(index=False))
        time.sleep(0.5)  # Wait for half a second before generating the next reading
except KeyboardInterrupt:
    print("Data generation stopped.")
)  # Wait for half a second before generating the next reading
except KeyboardInterrupt:
    print("Data generation stopped.")
# Out:
#      Time(s)   VOLT 1   VOLT 2  VOLT 3   VOLT 4   VOLT 5   VOLT 6   VOLT 7   VOLT 8   VOLT 9
# 1.714064e+09 1.038207 1.023776 1.02451 1.023095 0.985423 1.007065 1.031938 1.011124 1.034523
#      Time(s)   VOLT 1   VOLT 2   VOLT 3   VOLT 4   VOLT 5   VOLT 6   VOLT 7  VOLT 8   VOLT 9
# 1.714064e+09 1.043125 1.022608 1.024536 1.027982 1.001697 1.010878 1.033016 1.01101 1.022663
#      Time(s)   VOLT 1   VOLT 2   VOLT 3   VOLT 4   VOLT 5   VOLT 6   VOLT 7   VOLT 8   VOLT 9
# 1.714064e+09 1.043579 1.029822 1.022985 1.024776 1.000021 1.015796 1.037005 1.014442 1.036242
#      Time(s)   VOLT 1  VOLT 2   VOLT 3   VOLT 4   VOLT 5   VOLT 6   VOLT 7   VOLT 8   VOLT 9
# 1.714064e+09 1.033751 1.02888 1.034682 1.024518 0.995634 1.011825 1.018424 1.013476 1.039419
#      Time(s)   VOLT 1   VOLT 2   VOLT 3   VOLT 4   VOLT 5   VOLT 6   VOLT 7   VOLT 8   VOLT 9
# 1.714064e+09 1.047693 1.025701 1.020954 1.039173 0.995551 1.004742 1.021511 1.013575 1.029507
# ...
